# %% [markdown]
# # Tesis

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# Crea bounding boxes a todas las imagenes

# %%
import cv2
import os
import numpy as np

input_directories = [
    "dia",
    "doctor",
    "dulce",
    "granja",
    "mecanico",
    "montaña",
    "noche", 
    "playa",
    "saludable",
    "domestico"
    "salvaje"
]

# Ruta base del directorio de imágenes
base_image_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosAProcesar"
base_output_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados"

# Crear directorio de salida base si no existe
os.makedirs(base_output_directory, exist_ok=True)

# Procesar cada directorio
for directory in input_directories:
    image_directory = os.path.join(base_image_directory, directory)
    output_directory = os.path.join(base_output_directory, f"{directory}Etiquetado")

    # Crear directorio de salida para cada categoría si no existe
    os.makedirs(output_directory, exist_ok=True)

    print(f"Procesando imágenes en el directorio: {image_directory}")

    # Procesar cada imagen en el directorio
    for image_name in os.listdir(image_directory):
        image_path = os.path.join(image_directory, image_name)

        # Leer imagen en escala de grises
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"No se pudo leer la imagen {image_name} en {directory}")
            continue

        # Detectar bordes
        edges = cv2.Canny(image, 100, 200)
        kernel = np.ones((5, 5), np.uint8)
        # Aplicar dilatación
        dilated = cv2.dilate(edges, kernel, iterations=1)
        # Aplicar erosión
        kernelErosion = np.ones((7, 7), np.uint8)
        eroded = cv2.erode(dilated, kernelErosion, iterations=1)

        # Encontrar contornos
        contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Dibujar bounding box alrededor del área más grande
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            x, y, w, h = cv2.boundingRect(largest_contour)
            result = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)

            # Guardar la imagen procesada
            output_path = os.path.join(output_directory, image_name)
            cv2.imwrite(output_path, result)
            print(f"Imagen procesada guardada en {output_path}")
        else:
            print(f"No se encontraron contornos en {image_name} en {directory}")
# Out:
# Procesando imágenes en el directorio: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosAProcesar/doctor
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor281.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor509.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor114.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor69.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor681.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor314.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor380.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor571.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor564.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor491.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor402.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor245.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor387.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor390.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor470.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor370.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor388.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor123.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor623.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor654.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor466.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor604.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor637.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor701.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor468.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor46.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor501.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor186.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor674.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor206.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor335.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor524.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor395.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor483.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor342.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor222.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor556.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor171.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor142.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor480.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor634.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor450.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor449.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor678.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor156.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor377.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor317.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor228.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor141.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor624.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor174.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor551.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor243.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor427.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor586.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor55.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor354.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor697.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor610.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor540.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor165.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor286.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor548.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor227.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor415.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor543.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor290.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor561.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor37.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor236.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor460.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor275.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor403.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor08.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor511.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor533.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor613.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor638.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor436.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor36.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor653.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor515.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor541.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor439.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor304.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor618.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor17.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor690.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor617.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor225.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor381.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor270.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor239.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor356.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor585.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor512.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor494.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor510.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor100.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor110.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor531.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor406.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor187.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor478.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor358.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor704.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor189.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor196.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor49.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor686.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor336.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor379.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor135.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor111.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor224.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor425.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor408.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor692.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor65.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor351.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor385.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor469.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor199.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor240.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor601.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor513.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor502.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor254.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor147.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor463.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor276.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor520.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor92.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor190.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor413.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor555.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor605.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor124.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor687.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor188.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor287.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor104.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor284.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor303.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor301.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor62.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor505.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor316.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor22.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor146.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor581.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor703.png
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor441.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor459.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor273.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doctor153.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/doctorEtiquetado/doct
directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosAProcesar"
base_output_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados"

# Crear directorio de salida base si no existe
os.makedirs(base_output_directory, exist_ok=True)

# Procesar cada directorio
for directory in input_directories:
    image_directory = os.path.join(base_image_directory, directory)
    output_directory = os.path.join(base_output_directory, f"{directory}Etiquetado")
    os.makedirs(output_directory, exist_ok=True)

    print(f"Procesando imágenes en el directorio: {image_directory}")

    for image_name in os.listdir(image_directory):
        image_path = os.path.join(image_directory, image_name)

        # Leer imagen en escala de grises
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"No se pudo leer la imagen {image_name} en {directory}")
            continue

        # Suavizar imagen para reducir ruido
        blurred = cv2.GaussianBlur(image, (7, 7), 0)

        # Detectar bordes con Canny (ajusta los umbrales si es necesario)
        edges = cv2.Canny(blurred, 1, 5)

        # Dilatar y erosionar para cerrar huecos pequeños
        kernel = np.ones((9, 9), np.uint8)
        dilated = cv2.dilate(edges, kernel, iterations=4)
        eroded = cv2.erode(dilated, kernel, iterations=2)

 # Encontrar contornos
        contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Dibujar bounding box alrededor del área más grande
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            x, y, w, h = cv2.boundingRect(largest_contour)
            result = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)

            # Guardar la imagen procesada
            output_path = os.path.join(output_directory, image_name)
            cv2.imwrite(output_path, result)
            print(f"Imagen procesada guardada en {output_path}")
        else:
            print(f"No se encontraron contornos en {image_name} en {directory}")
'''
# Encontrar contornos
        contours, _ = cv2.findContours(eroded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Filtrar contornos por área mínima
        min_area = 1000  # Ajusta este valor según tus imágenes
        valid_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]

        # Dibujar bounding boxes para los contornos válidos
        result = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
        for contour in valid_contours:
            x, y, w, h = cv2.boundingRect(contour)
            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Guardar la imagen procesada
        output_path = os.path.join(output_directory, image_name)
        cv2.imwrite(output_path, result)
        print(f"Imagen procesada guardada en {output_path}")

'''
# Out:
# Procesando imágenes en el directorio: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosAProcesar/reDoctor
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/reDoctorEtiquetado/doctor47_aug_47.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/reDoctorEtiquetado/doctor46_aug_46.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/reDoctorEtiquetado/doctor26_aug_26.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/reDoctorEtiquetado/doctor48_aug_48.jpg
# Imagen procesada guardada en /home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados/reDoctorEtiquetado/doctor38_aug_38.jpg
# '\n# Encontrar contornos\n        contours, _ = cv2.findContours(eroded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)\n\n        # Filtrar contornos por área mínima\n        min_area = 1000  # Ajusta este valor según tus imágenes\n        valid_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]\n\n        # Dibujar bounding boxes para los contornos válidos\n        result = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)\n        for contour in valid_contours:\n            x, y, w, h = cv2.boundingRect(contour)\n            cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 2)\n\n        # Guardar la imagen procesada\n        output_path = os.path.join(output_directory, image_name)\n        cv2.imwrite(output_path, result)\n        print(f"Imagen procesada guardada en {output_path}")\n\n'

# %% [markdown]
# Se redimensiona las imagenes para tenerlas todas del mismo tamaño

# %%
import cv2
import os

# Configuración
input_directories = [
    "diaEtiquetado", 
    "doctorEtiquetado",
    "dulceEtiquetado",
    "granjaEtiquetado",
    "mecanicoEtiquetado",
    "montañaEtiquetado",
    "nocheEtiquetado",
    "playaEtiquetado",
    "saludableEtiquetado",
    "domesticoEtiquetado", 
    "salvajeEtiquetado"
]

# Ruta base del directorio de imágenes
base_image_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/Procesados"
base_output_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados"

target_size = (640, 640)  # Tamaño deseado para las imágenes (ancho, alto)

# Procesar las imágenes en cada directorio
for directory in input_directories:
    input_directory = os.path.join(base_image_directory, directory)
    output_directory = os.path.join(base_output_directory, directory)

    # Crear el directorio de salida si no existe
    os.makedirs(output_directory, exist_ok=True)

    # Verificar que el directorio de entrada existe
    if not os.path.exists(input_directory):
        print(f"El directorio de entrada no existe: {input_directory}")
        continue

    # Procesar las imágenes en el directorio actual
    for image_name in os.listdir(input_directory):
        input_path = os.path.join(input_directory, image_name)
        output_path = os.path.join(output_directory, image_name)

        # Verificar que el archivo sea una imagen
        if not image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(f"Saltando archivo no válido: {image_name}")
            continue

        # Leer la imagen
        image = cv2.imread(input_path)
        if image is None:
            print(f"No se pudo leer la imagen: {input_path}")
            continue

        # Redimensionar la imagen
        resized_image = cv2.resize(image, target_size)

        # Guardar la imagen redimensionada
        cv2.imwrite(output_path, resized_image)
        print(f"Imagen redimensionada y guardada en: {output_path}")

print("Redimensionamiento completado.")
# Out:
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor281.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor27_aug_27.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor509.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor114.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor69.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor681.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor314.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor380.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor571.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor564.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor491.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_07.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor40_aug_40.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor402.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor245.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor387.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor390.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor470.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor370.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor388.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor123.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor623.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor654.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor466.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor604.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor637.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor701.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor468.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor46.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor501.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor186.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor674.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor206.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor335.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor524.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor395.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor483.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor342.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor222.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor556.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor171.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor142.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor480.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor634.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor450.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor449.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor678.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor156.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor377.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor317.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor228.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor141.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor624.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor174.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor551.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor243.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor427.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor586.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor55.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor354.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor697.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor610.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor540.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor165.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor286.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor548.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor227.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor415.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor543.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor290.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor561.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor37.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor236.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor460.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor275.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor403.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor08.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor511.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor533.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor613.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor638.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor436.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor36.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor653.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor515.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor541.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor439.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor304.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor618.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor17.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor690.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor617.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor225.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor04_aug_04.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor381.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor270.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor239.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor356.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor585.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor512.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor494.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor510.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor100.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor110.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor531.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor406.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor187.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor478.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor358.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor704.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor189.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor196.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor49.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor686.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor336.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor379.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor135.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor111.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor224.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor425.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor408.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor49_aug_49.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor692.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor65.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor351.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor385.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor469.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor199.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor240.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor50_aug_50.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor601.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor513.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor502.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor254.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor147.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor05_aug_05.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor463.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor276.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor520.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor92.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor190.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor413.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor555.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor605.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor124.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor687.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor188.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor287.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor104.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor284.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor303.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_10.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor301.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor62.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor505.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_20.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor316.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor22.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor146.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor581.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor703.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor441.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor459.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor273.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor153.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor447.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor252.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor626.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor364.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor669.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor193.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor584.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor55_aug_55.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor489.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor526.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor677.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor496.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor528.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor517.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor576.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor235.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor119.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor195.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor106.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor28.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor168.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor407.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor330.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor167.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor507.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor184.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor620.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor693.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor673.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor162.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor30_aug_30.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor362.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor595.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor26.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor599.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor559.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor271.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor600.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor66.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor691.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor493.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor262.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor198.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor569.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor652.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor683.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor621.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor549.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor67.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor218.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_01.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor485.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor318.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor641.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor473.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor420.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor372.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor02.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor269.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor209.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_25.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor597.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor454.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_11.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor161.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor143.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor164.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor56.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor396.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor530.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor197.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor30.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor327.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor180.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor155.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor121.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor367.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor486.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor40.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor699.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor536.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor602.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor518.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor149.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor182.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor32_aug_32.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor345.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor226.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor422.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor332.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor323.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor589.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor211.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor503.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor33.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor264.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor265.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor07.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor583.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor365.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor02_aug_02.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor230.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor544.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor280.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor397.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor220.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor702.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor296.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor293.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor497.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor259.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor19.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor694.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor481.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor299.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor635.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor260.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor629.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor328.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor592.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor229.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor279.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor150.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor292.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor472.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor295.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor393.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor630.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_02.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_15.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor_aug_12.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor20.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor63.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor361.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor68.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor27.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor219.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor552.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor278.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor80.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor274.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor200.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor01_aug_01.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor23.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor433.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor700.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor309.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor87.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor329.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor134.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor107.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor09.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor685.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor294.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor74.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor411.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor667.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor684.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor391.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor580.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor554.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor131.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor404.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor191.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor696.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor192.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor16.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor130.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor70.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor151.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor88.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor632.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor418.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/doctorEtiquetado/doctor324.jpg
# ...
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje357.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje473.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje824.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1022.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje61.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje568.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje344.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje303.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje171.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje217.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje715.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje638.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje582.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje131.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje273.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1051.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje370.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje592.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje380.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje828.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje08.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje701.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje433.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje488.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje250.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje912.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje296.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje598.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje231.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje09.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje988.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje706.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje183.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje414.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje267.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje614.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje37.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje440.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje139.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje855.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje435.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje748.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1231.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje115.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje722.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje456.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1074.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje146.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje22.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1110.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje812.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje943.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje207.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje631.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje925.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje541.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje63.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje214.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje161.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje843.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje675.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje714.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje807.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje780.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje272.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje885.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1163.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1126.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje778.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje399.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje570.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje332.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje415.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje903.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje937.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje874.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje441.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1138.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje564.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1224.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje552.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje708.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje671.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1117.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1096.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje172.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje803.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje30.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje998.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1133.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1000.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1162.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje980.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje10.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje651.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje500.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje837.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje905.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje655.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje620.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje309.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1158.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje195.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje353.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje483.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1207.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje804.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje920.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje1120.png
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje901.jpg
# Imagen redimensionada y guardada en: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados/salvajeEtiquetado/salvaje284.jpg
# Redimensionamiento completado.

# %% [markdown]
# Se etiquetan las imagenes

# %%
import cv2
import os

base_input_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosRedimencionados"
input_directories = [
    "doctorEtiquetado", 
    "mecanicoEtiquetado",
    "domesticoEtiquetado",
    "salvajeEtiquetado",
    "nocheEtiquetado", 
    "diaEtiquetado",
    "montañaEtiquetado", 
    "playaEtiquetado",
    "granjaEtiquetado",
    "dulceEtiquetado",
    "saludableEtiquetado"
]
labels_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/Labels"
os.makedirs(labels_directory, exist_ok=True)

for category_id, input_directory in enumerate(input_directories):
    print(f"Procesando directorio: {input_directory}")
    category_input_dir = os.path.join(base_input_directory, input_directory)
    category_labels_dir = os.path.join(labels_directory, input_directory)
    os.makedirs(category_labels_dir, exist_ok=True)

    for image_name in os.listdir(category_input_dir):
        if not image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue
        
        image_path = os.path.join(category_input_dir, image_name)
        image = cv2.imread(image_path)
        if image is None:
            print(f"No se pudo leer la imagen {image_path}")
            continue

        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        edges = cv2.Canny(gray_image, 150, 250)
        contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            if cv2.contourArea(largest_contour) < 10:
                print(f"Contorno demasiado pequeño en {image_path}")
                continue

            x, y, w, h = cv2.boundingRect(largest_contour)
            img_h, img_w = gray_image.shape
            x_center = (x + w / 2) / img_w
            y_center = (y + h / 2) / img_h
            width = w / img_w
            height = h / img_h
            yolo_format = f"{category_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}"
            txt_name = os.path.splitext(image_name)[0] + ".txt"
            txt_path = os.path.join(category_labels_dir, txt_name)

            with open(txt_path, "w") as f:
                f.write(yolo_format + "\n")
        else:
            print(f"No se encontraron contornos en {image_path}")
# Out:
# Procesando directorio: doctorEtiquetado
# Procesando directorio: playaEtiquetado
# Procesando directorio: salvajeEtiquetado

# %% [markdown]
# Se dividen las imagenes

# %%
import os
import random
import shutil

def split_dataset(data_dir, train_dir, test_dir, test_size=0.3):
    """
    Divide las imágenes y sus archivos .txt correspondientes en conjuntos de entrenamiento y prueba de forma aleatoria.

    :param data_dir: Directorio donde están todas las imágenes y sus archivos .txt.
    :param train_dir: Directorio donde se guardarán las imágenes y .txt de entrenamiento.
    :param test_dir: Directorio donde se guardarán las imágenes y .txt de prueba.
    :param test_size: Proporción de imágenes para el conjunto de prueba (por defecto, 0.3 para 30%).
    """
    # Crear los directorios de salida si no existen
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Obtener la lista de todas las imágenes (asumiendo extensión .jpg o .png)
    all_images = [f for f in os.listdir(data_dir) if f.endswith(('.jpg', '.png'))]

    # Mezclar las imágenes aleatoriamente
    random.shuffle(all_images)

    # Calcular el número de imágenes para el conjunto de prueba
    num_test = int(len(all_images) * test_size)

    # Dividir las imágenes
    test_images = all_images[:num_test]
    train_images = all_images[num_test:]

    # Mover las imágenes y sus archivos .txt al directorio correspondiente
    for img in train_images:
        img_path = os.path.join(data_dir, img)
        txt_path = os.path.join(data_dir, os.path.splitext(img)[0] + '.txt')

        shutil.copy(img_path, os.path.join(train_dir, img))
        if os.path.exists(txt_path):
            shutil.copy(txt_path, os.path.join(train_dir, os.path.basename(txt_path)))

    for img in test_images:
        img_path = os.path.join(data_dir, img)
        txt_path = os.path.join(data_dir, os.path.splitext(img)[0] + '.txt')

        shutil.copy(img_path, os.path.join(test_dir, img))
        if os.path.exists(txt_path):
            shutil.copy(txt_path, os.path.join(test_dir, os.path.basename(txt_path)))

    print(f"Conjunto dividido exitosamente:")
    print(f"  Imágenes de entrenamiento: {len(train_images)}")
    print(f"  Imágenes de prueba: {len(test_images)}")

# Configuración de directorios
data_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/Train"
train_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTrain"
test_directory = "/home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTest"

# Llamar a la función con una proporción de prueba del 30%
split_dataset(data_directory, train_directory, test_directory, test_size=0.3)
# Out:
# Conjunto dividido exitosamente:
#   Imágenes de entrenamiento: 5858
#   Imágenes de prueba: 2510

# %% [markdown]
# ## Entrenamiento con Yolov5

# %%
# Crear archivo data.yaml con las rutas y clases correctas
with open('database.yaml', 'w') as f:
    f.write("""
train: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTrain
val: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTest

nc: 11
names: ['doctor', 'mecanico', 'domestico', 'salvaje', 'noche', 'dia', 'montaña', 'playa', 'granja', 'dulce', 'saludable']

""")

# %%
# Clonar el repositorio de YOLOv5
# !git clone https://github.com/ultralytics/yolov5.git

# %pip install -r yolov5/requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %%
# !python "/home/andres/ambientesVirtuales/PruebasML/Practicas/Tesis/yolov5/train.py" --img 640 --batch 16 --epochs 200 --data database.yaml --weights yolov5s.pt --device 0 --project "/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados" --name experiment2
# Out:
# train: weights=yolov5s.pt, cfg=, data=database.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados, name=experiment2, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 7 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 3806MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     43152  models.yolo.Detect                      [11, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7049296 parameters, 7049296 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# train: Scanning /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrena
# train: New cache created: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTrain.cache
# val: Scanning /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenami
# val: New cache created: /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenamiento/newTest.cache
#
# AutoAnchor: 2.26 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/199      3.44G    0.06964    0.02345    0.06117          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.135      0.108     0.0748     0.0382
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/199      3.13G     0.0468    0.01838    0.05491          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.283      0.129      0.124     0.0695
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/199      3.13G     0.0452    0.01777    0.05181          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.341      0.325      0.211     0.0957
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/199      3.14G    0.04528    0.01792    0.04758          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.368      0.291      0.243      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/199      3.14G    0.04353     0.0179    0.04665          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.477      0.357      0.319       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/199      3.14G    0.04254    0.01768    0.04339          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.556      0.452      0.423      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/199      3.14G    0.04051    0.01731    0.04044          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.558      0.437      0.441      0.281
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/199      3.14G    0.03985    0.01728    0.03978          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.453      0.491       0.43      0.279
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/199      3.14G    0.03838    0.01722    0.03818          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.494      0.492      0.472      0.299
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/199      3.14G    0.03877    0.01691    0.03751          2        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517       0.51      0.519      0.479      0.321
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/199      3.14G    0.03876    0.01697    0.03673          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.547      0.508      0.492      0.331
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/199      3.14G    0.03784    0.01707    0.03694          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.548      0.553      0.523      0.335
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/199      3.14G    0.03727    0.01668    0.03487          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.586      0.564      0.554      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/199      3.14G    0.03701      0.017    0.03369          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.591      0.555      0.545      0.377
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/199      3.14G    0.03682    0.01718    0.03215          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.557      0.523       0.51      0.332
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/199      3.14G    0.03702    0.01711    0.03331          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.609      0.587      0.587      0.395
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/199      3.14G    0.03542    0.01692    0.03247          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.588      0.583      0.569      0.389
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/199      3.14G    0.03582    0.01659    0.03064          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.621      0.602      0.599      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/199      3.14G    0.03706    0.01655    0.02999          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.621      0.624       0.61      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/199      3.14G    0.03591    0.01673    0.02912          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.642      0.613      0.616       0.43
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/199      3.14G    0.03544     0.0165    0.02926          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.684      0.621      0.637      0.464
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/199      3.14G    0.03491    0.01659      0.027          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.656      0.636      0.628      0.441
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/199      3.14G    0.03559    0.01689    0.02653          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.657      0.613      0.631      0.453
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/199      3.14G    0.03553    0.01646    0.02732          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.637      0.609      0.615      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/199      3.14G    0.03522    0.01681    0.02685          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.657      0.616       0.63      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/199      3.14G    0.03507    0.01646    0.02618          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.666      0.633      0.644      0.461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/199      3.14G    0.03351     0.0162    0.02583          2        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.647      0.645      0.649      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/199      3.14G    0.03308     0.0161    0.02496          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.692      0.643       0.66      0.494
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/199      3.14G     0.0335    0.01614    0.02587          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.618      0.644      0.637      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/199      3.14G    0.03435    0.01625    0.02467          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.652      0.639      0.633      0.471
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/199      3.14G    0.03485    0.01609    0.02368          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.655      0.649      0.651      0.493
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/199      3.14G    0.03328    0.01621    0.02322          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0
0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     198/199      3.14G    0.01746    0.01237   0.004816          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.735      0.751      0.764      0.666
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     199/199      3.14G    0.01632    0.01214    0.00446          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.736      0.752      0.764      0.665
#
# 200 epochs completed in 10.120 hours.
# Optimizer stripped from /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/last.pt, 14.5MB
# Optimizer stripped from /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt, 14.5MB
#
# Validating /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.737      0.751      0.764      0.666
#                 doctor       2510        216        0.6      0.634      0.656      0.579
#               mecanico       2510        178      0.875      0.905      0.933       0.84
#              domestico       2510        303      0.912      0.937      0.951      0.851
#                salvaje       2510        321      0.903      0.931       0.94      0.877
#                  noche       2510        216      0.722      0.817      0.843      0.736
#                    dia       2510        153      0.717       0.66      0.657      0.509
#                montaña       2510        267      0.615      0.712       0.71      0.608
#                  playa       2510        302      0.555      0.599       0.56      0.466
#                 granja       2510        226      0.458      0.332      0.357      0.278
#                  dulce       2510        171      0.869      0.855      0.902      0.799
#              saludable       2510        164      0.884      0.872      0.899      0.781
# Results saved to /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27

# %% [markdown]
# ### Validar el modelo

# %%
#!python detect.py --weights /content/drive/MyDrive/tesis/resultados/experiment12/weights/best.pt --img 640 --source /content/drive/MyDrive/tesis/new_dataset/test/ic129.png
# !python "/home/andres/ambientesVirtuales/PruebasML/Practicas/Tesis/yolov5/val.py" --data database.yaml --weights "/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt" --img 640 --device 0
# Out:
# val: data=database.yaml, weights=['/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 3806MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /home/andres/ambientesVirtuales/PruebasML/Practicas/DatosEntrenami
#                  Class     Images  Instances          P          R      mAP50
#                    all       2510       2517      0.738      0.751      0.764      0.665
#                 doctor       2510        216        0.6      0.634      0.656      0.579
#               mecanico       2510        178      0.875      0.905      0.933      0.839
#              domestico       2510        303      0.912      0.937      0.951       0.85
#                salvaje       2510        321      0.904      0.931       0.94      0.876
#                  noche       2510        216      0.722      0.818      0.844      0.736
#                    dia       2510        153      0.719       0.66      0.658      0.509
#                montaña       2510        267      0.615      0.712       0.71      0.607
#                  playa       2510        302      0.555      0.599       0.56      0.466
#                 granja       2510        226      0.463      0.336      0.356      0.277
#                  dulce       2510        171      0.869      0.855      0.902      0.797
#              saludable       2510        164      0.884      0.872      0.899      0.781
# Speed: 0.4ms pre-process, 14.0ms inference, 2.0ms NMS per image at shape (32, 3, 640, 640)
# Results saved to yolov5/runs/val/exp2

# %% [markdown]
# ### Exportar el modelo

# %%
# !python "/home/andres/ambientesVirtuales/PruebasML/Practicas/Tesis/yolov5/export.py" --weights "/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt" --img 640 --batch 1 --device 0 --include torchscript
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt'], imgsz=[640], batch_size=1, device=0, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript']
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 3806MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7039792 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.pt with output shape (1, 25200, 16) (13.8 MB)
#
# TorchScript: starting export with torch 2.3.1+cu121...
# TorchScript: export success ✅ 0.7s, saved as /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.torchscript (27.3 MB)
#
# Export complete (1.3s)
# Results saved to /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights
# Detect:          python detect.py --weights /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.torchscript
# Validate:        python val.py --weights /home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.torchscript
# PyTorch Hub:     model = torch.hub.load('ultralytics/yolov5', 'custom', '/home/andres/ambientesVirtuales/PruebasML/Practicas/resultados/experiment27/weights/best.torchscript')
# Visualize:       https://netron.app
